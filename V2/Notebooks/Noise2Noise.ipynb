# %%
# pip install torch torchvision torchaudio librosa matplotlib

# %%
import librosa
import soundfile as sf
import numpy as np 
import os
import torch
import pickle

from torch.utils.tensorboard import SummaryWriter

# %%
print(np.__version__)
# Out:
# 1.24.3

# %%
# import torch.multiprocessing as mp
# mp.set_start_method('spawn', force=True)

# %%
#setup up device 
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %%
import os

import numpy as np
from torch.utils.data import Dataset


def load_fsdd(spectrograms_path):
    x_train = []
    for root, _, file_names in os.walk(spectrograms_path):
        for file_name in file_names:
            file_path = os.path.join(root, file_name)
            spectrogram = np.load(file_path) # (n_bins, n_frames, 1)
            x_train.append(spectrogram)
    x_train = np.array(x_train)
    x_train = x_train[..., np.newaxis] # -> (3000, 256, 64, 1)
    return x_train

def load_spectrogram(spectrogram_path):
    spectrogram = np.load(spectrogram_path, allow_pickle=True)
    spectrogram = torch.tensor(spectrogram, dtype = torch.float32)
    return spectrogram

class AudioDataSetCustom(Dataset):
    def __init__(self, clean_speech_paths, noisy_speech_paths):
        self.clean_speech_paths = clean_speech_paths
        self.noisy_speech_paths = noisy_speech_paths

    def __len__(self):
        return len(self.clean_speech_paths)

    def __getitem__(self, index):
        clean_speech, noisy_speech = load_spectrogram(self.clean_speech_paths[index]), load_spectrogram(self.noisy_speech_paths[index])
        
        clean_speech = clean_speech.unsqueeze(0)
        noisy_speech = noisy_speech.unsqueeze(0)
        return clean_speech, noisy_speech

# %%
#create AudioDataSetCustom object
#get clean speech paths from directory
import glob
clean_dir = '../input/spectrograms/clean'
noisy_dir = '../input/spectrograms/noise'
clean_files = glob.glob(os.path.join(clean_dir + '/'+'*.npy'))
noisy_files = glob.glob(os.path.join(noisy_dir + '/'+'*.npy'))

# %%
clean_files = [clean_file.replace('\\', '/')for clean_file in clean_files]
noisy_files = [noisy_file.replace('\\', '/')for noisy_file in noisy_files]

# %%
from sklearn.model_selection import train_test_split

clean_train, clean_test, noisy_train, noisy_test = train_test_split(
    clean_files, noisy_files, test_size=0.2, random_state=42)

train_dataset = AudioDataSetCustom(clean_train,noisy_train)
test_dataset = AudioDataSetCustom(clean_test,noisy_test)

# %%
clean_speech_spec, noisy_speech_spec = train_dataset[69][0], train_dataset[69][1]

# %%
class SoundGenerator:
    """SoundGenerator is responsible for generating audios from
    spectrograms.
    """

    def __init__(self, hop_length):
        self.hop_length = hop_length
        self._min_max_normaliser = MinMaxNormaliser(0, 1)

    def generate(self, spectrograms, min_max_values):
        signals = self.convert_spectrograms_to_audio(spectrograms, min_max_values)
        return signals

    def convert_spectrograms_to_audio(self, log_spectrogram, min_max_value):
        
        # apply denormalisation
        denorm_log_spec = self._min_max_normaliser.denormalise(
            log_spectrogram, torch.tensor(min_max_value["min"], dtype = torch.float32), torch.tensor(min_max_value["max"], dtype = torch.float32))
        # log spectrogram -> spectrogram
        print("type of the array is " + str(type(denorm_log_spec.numpy())))
        spec = librosa.db_to_amplitude(denorm_log_spec.numpy())
        spec = spec[0,:,:] # remove the first dimension (also could use squeeze() function )
        print(f"shape of the spec is {spec.shape}")
        # Todo: remove this later 
        spec = np.pad(spec, ((0, 1), (0, 0)), mode='constant')
        
        # apply Griffin-Lim
        reconstructed_signal = librosa.griffinlim(spec,
                                                  n_iter=50,
                                                  hop_length=HOP_LENGTH,
                                                  win_length=FRAME_SIZE,
                                                  n_fft=FRAME_SIZE)
        return reconstructed_signal

# %%
class MinMaxNormaliser:
    """MinMaxNormaliser applies min max normalisation to an array."""

    def __init__(self, min_val, max_val):
        self.min = min_val
        self.max = max_val

    def normalise(self, array):
        norm_array = (array - array.min()) / (array.max() - array.min())
        norm_array = norm_array * (self.max - self.min) + self.min
        return norm_array

    def denormalise(self, norm_array, original_min, original_max):
        array = (norm_array - self.min) / (self.max - self.min)
        array = array * (original_max - original_min) + original_min
        return array

# %%
import pickle 
min_max_values = None
with open('..\input\min_max_values.pkl', "rb") as file:
    min_max_values = pickle.load(file)

# %%
# get a random file path with min max values 
path = train_dataset.clean_speech_paths[69]
min_max_value = min_max_values[path[3:]]
clean_speech_spec
print("Necessary things for audio extraction from specs")
# Out:
# Necessary things for audio extraction from specs

# %%
FRAME_SIZE = 1024
HOP_LENGTH = 512
DURATION = 7  # in seconds
SAMPLE_RATE = 16000
MONO = True

# %%
soundGen = SoundGenerator(hop_length = HOP_LENGTH)

# %%
signals = soundGen.generate(clean_speech_spec, min_max_value)
# Out:
# type of the array is <class 'numpy.ndarray'>
# shape of the spec is (512, 219)

# %%
signals
# Out:
# array([ 0.00249047,  0.0017984 ,  0.00229239, ..., -0.14474688,
#        -0.07029667, -0.00206537], dtype=float32)

# %%
path = train_dataset.clean_speech_paths[269]
min_max_value = min_max_values[path[3:]]
clean_speech_spec, noisy_speech_spec = train_dataset[269][0], train_dataset[269][1]
signals = soundGen.generate(clean_speech_spec, min_max_value)
# Out:
# type of the array is <class 'numpy.ndarray'>
# shape of the spec is (512, 219)

# %%
signals
# Out:
# array([ 0.00129832, -0.00041587, -0.00242489, ..., -0.09391142,
#        -0.08721228, -0.06812534], dtype=float32)

# %%
ipd.Audio(signals, rate = 16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#signals to audio
sf.write('test.wav',signals, 16000)

# %%
len(signals ) / 16000 # in seconds
# Out:
# 6.976

# %%
from torch.utils.data import DataLoader

train_dataloader = DataLoader(dataset=train_dataset, 
                              batch_size=128, # how many samples per batch?
                              num_workers=0, # how many subprocesses to use for data loading? (higher = more)
                              shuffle=True) # shuffle the data?

test_dataloader = DataLoader(dataset=test_dataset, 
                             batch_size=128, 
                             num_workers=0, 
                             shuffle=False) # don't usually need to shuffle testing data

# %%
clean_speech, noisy_speech = next(iter(train_dataloader))

# %%
clean_speech.shape
# Out:
# torch.Size([128, 1, 512, 219])

# %% [markdown]
# ## Model

# %%
writer = SummaryWriter()

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class DenoisingAutoencoder(nn.Module):
    def __init__(self):
        super(DenoisingAutoencoder, self).__init__()
        # Encoder
        self.encoder = nn.Sequential(
            nn.Conv2d(1, 16, kernel_size=3, stride=2, padding=1),  # Output: (16, 256, 110)
            nn.ReLU(),
            nn.Conv2d(16, 32, kernel_size=3, stride=2, padding=1), # Output: (32, 128, 55)
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=3, stride=2, padding=1), # Output: (64, 64, 28)
            nn.ReLU()
        )

        # Decoder
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(64, 32, kernel_size=3, stride=2, padding=1, output_padding=(0,1)),  # Output: (32, 128, 56)
            nn.ReLU(),
            nn.ConvTranspose2d(32, 16, kernel_size=3, stride=2, padding=1, output_padding=(0,1)),  # Output: (16, 256, 112)
            nn.ReLU(),
            nn.Upsample(size=(512, 219), mode='bilinear', align_corners=False),  # Ensure it matches the input
            nn.ConvTranspose2d(16, 1, kernel_size=3, stride=1, padding=1),  # Adjust this as needed
            nn.Tanh()
        )
    
    def forward(self, x):
        #pad the input to get the desired length
        x = self.encoder(x)
        x = self.decoder(x)
        return x
model = DenoisingAutoencoder().to(device)
print(model)
next(model.parameters()).device #Check model device
# Out:
# DenoisingAutoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): ReLU()
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(0, 1))
#     (1): ReLU()
#     (2): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(0, 1))
#     (3): ReLU()
#     (4): Upsample(size=(512, 219), mode='bilinear')
#     (5): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): Tanh()
#   )
# )
# device(type='cuda', index=0)

# %%
import torch.optim as optim 

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr = 0.001)


def train_step(model: torch.nn.Module,
               data_loader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer,
               epoch,
               device: torch.device = device):
    train_loss = 0
    model.to(device)
    for data in data_loader:
        clean_speech, noisy_speech = data
        clean_speech, noisy_speech = clean_speech.to(device), noisy_speech.to(device)
        

        # Zero the gradients
        optimizer.zero_grad()
        
        # Forward pass
        output = model(noisy_speech)
        
        
        # Compute the loss
        loss = loss_fn(output, clean_speech)
        
        train_loss += loss
        
        # Backward pass and optimize
        loss.backward()
        optimizer.step()

    # Calculate loss and accuracy per epoch and print out what's happening
    train_loss /= len(data_loader)
    writer.add_scalar('loss/train', train_loss,epoch)
    print(f"Train loss: {train_loss:.5f} ")

# %%
torch.manual_seed(69)
def test_step(model: torch.nn.Module, 
               data_loader: torch.utils.data.DataLoader, 
               loss_fn: torch.nn.Module,
               epoch:int):
    loss  = 0
    model.to(device)
    model.eval()
    with torch.inference_mode():
        for X, y in data_loader:
            # Make predictions with the model
            X, y = X.to(device), y.to(device)
            y_pred = model(X)
            
            # Accumulate the loss and accuracy values per batch
            loss += loss_fn(y_pred, y)
    
        # Scale loss and acc to find the average loss/acc per batch
        loss /= len(data_loader)
        
    writer.add_scalar('loss/test', loss,epoch)    
    return {"model_name": model.__class__.__name__, # only works when model was created with a class
            "model_loss": loss.item()}

# %%
def eval_model(model: torch.nn.Module, 
               data_loader: torch.utils.data.DataLoader, 
               loss_fn: torch.nn.Module):
    loss =0
    model.eval()
    with torch.inference_mode():
        for X, y in data_loader:
            # Make predictions with the model
            X, y = X.to(device), y.to(device)
            y_pred = model(X)
            
            # Accumulate the loss and accuracy values per batch
            loss += loss_fn(y_pred, y)
   
        # Scale loss and acc to find the average loss/acc per batch
        loss /= len(data_loader)
        
    return {"model_name": model.__class__.__name__, # only works when model was created with a class
            "model_loss": loss.item()}

# %%
def print_train_time(start: float, end: float, device: torch.device = None):
    """Prints difference between start and end time.

    Args:
        start (float): Start time of computation (preferred in timeit format). 
        end (float): End time of computation.
        device ([type], optional): Device that compute is running on. Defaults to None.

    Returns:
        float: time between start and end in seconds (higher is longer).
    """
    total_time = end - start
    print(f"Train time on {device}: {total_time:.3f} seconds")
    return total_time

# %%
torch.manual_seed(69)

# Measure time
from timeit import default_timer as timer
from tqdm import tqdm
train_time_start_on_gpu = timer()

epochs = 30
for epoch in tqdm(range(epochs)):
    print(f"Epoch: {epoch}\n---------")
    train_step(data_loader=train_dataloader, 
        model=model, 
        loss_fn=criterion,
        optimizer=optimizer,
        epoch = epoch
    )
    test_step(data_loader=test_dataloader,
        model=model,
        loss_fn=criterion,
        epoch = epoch
    )

train_time_end_on_gpu = timer()
total_train_time_model_1 = print_train_time(start=train_time_start_on_gpu,
                                            end=train_time_end_on_gpu,
                                            device=device)
# Out:
#   0%|                                                                                           | 0/30 [00:00<?, ?it/s]
# Epoch: 0
# ---------
# Train loss: 0.04208
#   3%|██▊                                                                                | 1/30 [00:37<18:13, 37.70s/it]
# Epoch: 1
# ---------
# Train loss: 0.02963
#   7%|█████▌                                                                             | 2/30 [01:13<17:01, 36.48s/it]
# Epoch: 2
# ---------
# Train loss: 0.02456
#  10%|████████▎                                                                          | 3/30 [01:48<16:14, 36.10s/it]
# Epoch: 3
# ---------
# Train loss: 0.02232
#  13%|███████████                                                                        | 4/30 [02:26<15:48, 36.49s/it]
# Epoch: 4
# ---------
# Train loss: 0.02148
#  17%|█████████████▊                                                                     | 5/30 [03:04<15:27, 37.12s/it]
# Epoch: 5
# ---------
# Train loss: 0.02085
#  20%|████████████████▌                                                                  | 6/30 [03:48<15:48, 39.53s/it]
# Epoch: 6
# ---------
# Train loss: 0.02039
#  23%|███████████████████▎                                                               | 7/30 [04:32<15:43, 41.03s/it]
# Epoch: 7
# ---------
# Train loss: 0.02011
#  27%|██████████████████████▏                                                            | 8/30 [05:16<15:22, 41.92s/it]
# Epoch: 8
# ---------
# Train loss: 0.01997
#  30%|████████████████████████▉                                                          | 9/30 [06:00<14:51, 42.44s/it]
# Epoch: 9
# ---------
# Train loss: 0.01978
#  33%|███████████████████████████▎                                                      | 10/30 [06:44<14:24, 43.21s/it]
# Epoch: 10
# ---------
# Train loss: 0.01963
#  37%|██████████████████████████████                                                    | 11/30 [07:29<13:50, 43.70s/it]
# Epoch: 11
# ---------
# Train loss: 0.01924
#  40%|████████████████████████████████▊                                                 | 12/30 [08:15<13:19, 44.40s/it]
# Epoch: 12
# ---------
# Train loss: 0.01919
#  43%|███████████████████████████████████▌                                              | 13/30 [08:59<12:28, 44.05s/it]
# Epoch: 13
# ---------
# Train loss: 0.01914
#  47%|██████████████████████████████████████▎                                           | 14/30 [09:44<11:50, 44.40s/it]
# Epoch: 14
# ---------
# Train loss: 0.01920
#  50%|█████████████████████████████████████████                                         | 15/30 [10:29<11:11, 44.79s/it]
# Epoch: 15
# ---------
# Train loss: 0.01907
#  53%|███████████████████████████████████████████▋                                      | 16/30 [11:12<10:19, 44.27s/it]
# Epoch: 16
# ---------
# Train loss: 0.01888
#  57%|██████████████████████████████████████████████▍                                   | 17/30 [11:57<09:35, 44.30s/it]
# Epoch: 17
# ---------
# Train loss: 0.01873
#  60%|█████████████████████████████████████████████████▏                                | 18/30 [12:35<08:28, 42.35s/it]
# Epoch: 18
# ---------
# Train loss: 0.01847
#  63%|███████████████████████████████████████████████████▉                              | 19/30 [13:03<07:00, 38.26s/it]
# Epoch: 19
# ---------
# Train loss: 0.01864
#  67%|██████████████████████████████████████████████████████▋                           | 20/30 [13:32<05:54, 35.41s/it]
# Epoch: 20
# ---------
# Train loss: 0.01850
#  70%|█████████████████████████████████████████████████████████▍                        | 21/30 [14:01<05:01, 33.49s/it]
# Epoch: 21
# ---------
# Train loss: 0.01827
#  73%|████████████████████████████████████████████████████████████▏                     | 22/30 [14:31<04:18, 32.37s/it]
# Epoch: 22
# ---------
# Train loss: 0.01830
#  77%|██████████████████████████████████████████████████████████████▊                   | 23/30 [14:58<03:35, 30.76s/it]
# Epoch: 23
# ---------
# Train loss: 0.01814
#  80%|█████████████████████████████████████████████████████████████████▌                | 24/30 [15:23<02:53, 28.95s/it]
# Epoch: 24
# ---------
# Train loss: 0.01801
#  83%|████████████████████████████████████████████████████████████████████▎             | 25/30 [15:47<02:17, 27.42s/it]
# Epoch: 25
# ---------
# Train loss: 0.01794
#  87%|███████████████████████████████████████████████████████████████████████           | 26/30 [16:11<01:45, 26.39s/it]
# Epoch: 26
# ---------
# Train loss: 0.01790
#  90%|█████████████████████████████████████████████████████████████████████████▊        | 27/30 [16:35<01:17, 25.82s/it]
# Epoch: 27
# ---------
# Train loss: 0.01784
#  93%|████████████████████████████████████████████████████████████████████████████▌     | 28/30 [17:00<00:51, 25.64s/it]
# Epoch: 28
# ---------
# Train loss: 0.01796
#  97%|███████████████████████████████████████████████████████████████████████████████▎  | 29/30 [17:25<00:25, 25.43s/it]
# Epoch: 29
# ---------
# Train loss: 0.01793
# 100%|██████████████████████████████████████████████████████████████████████████████████| 30/30 [17:59<00:00, 35.97s/it]
# Train time on cuda: 1079.050 seconds

# %%
torch.cuda.is_available()
# Out:
# True

# %%
# Saving the model 

MODEL_SAVE_DIR = "models/"
MODEL_NAME = "BasicAutoEncoder.pth"
MODEL_PATH = MODEL_SAVE_DIR+ MODEL_NAME

def save_model(obj, model_path):
    torch.save(obj = model.state_dict(),
          f = model_path)


save_model(model, MODEL_PATH)

# %%
def load_model(model, load_path):
    model.load_state_dict(torch.load(f = load_path))

# %%
loaded_model = DenoisingAutoencoder().to(device)
load_model(loaded_model, MODEL_PATH )
# Out:
# C:\Users\Mani Teja Varma\AppData\Local\Temp\ipykernel_21416\3335735561.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f = load_path))

# %%
loaded_model
# Out:
# DenoisingAutoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(1, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (1): ReLU()
#     (2): Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (3): ReLU()
#     (4): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (5): ReLU()
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(0, 1))
#     (1): ReLU()
#     (2): ConvTranspose2d(32, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(0, 1))
#     (3): ReLU()
#     (4): Upsample(size=(512, 219), mode='bilinear')
#     (5): ConvTranspose2d(16, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): Tanh()
#   )
# )

# %%
#Evaluating the model 
torch.manual_seed(69)
model_results = eval_model(
    model=model,
    data_loader=test_dataloader,
    loss_fn=criterion
)
loaded_model_results = eval_model(
    model=loaded_model,
    data_loader=test_dataloader,
    loss_fn=criterion
)
print(f" {loaded_model_results}, {model_results}")
# Out:
#  {'model_name': 'DenoisingAutoencoder', 'model_loss': 0.03022965043783188}, {'model_name': 'DenoisingAutoencoder', 'model_loss': 0.03022965043783188}

# %%
# Generate the audio from the spectrograms and listen to see the difference

# %%
# get a random file path with min max values 
clean_speech_spec, noisy_speech_spec = train_dataset[69][0], train_dataset[69][1]
path = train_dataset.noisy_speech_paths[69]
min_max_value = min_max_values[path[3:]]

signals = soundGen.generate(noisy_speech_spec, min_max_value)
# Out:
# type of the array is <class 'numpy.ndarray'>
# shape of the spec is (512, 219)

# %%
def generate_sound(noise_spec, path):
    min_max_value = min_max_values[path[3:]]
    return soundGen.generate(noisy_speech_spec, min_max_value)

# %%
signals.shape
# Out:
# (111616,)

# %%
import IPython.display as ipd

ipd.Audio(signals, rate = 16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
train_dataset.noisy_speech_paths
# Out:
# ['../input/spectrograms/noise/noisy_speech_1838..npy',
#  '../input/spectrograms/noise/noisy_speech_508..npy',
#  '../input/spectrograms/noise/noisy_speech_2..npy',
#  '../input/spectrograms/noise/noisy_speech_649..npy',
#  '../input/spectrograms/noise/noisy_speech_1109..npy',
#  '../input/spectrograms/noise/noisy_speech_1383..npy',
#  '../input/spectrograms/noise/noisy_speech_1353..npy',
#  '../input/spectrograms/noise/noisy_speech_1525..npy',
#  '../input/spectrograms/noise/noisy_speech_177..npy',
#  '../input/spectrograms/noise/noisy_speech_1033..npy',
#  '../input/spectrograms/noise/noisy_speech_675..npy',
#  '../input/spectrograms/noise/noisy_speech_296..npy',
#  '../input/spectrograms/noise/noisy_speech_1297..npy',
#  '../input/spectrograms/noise/noisy_speech_1790..npy',
#  '../input/spectrograms/noise/noisy_speech_1366..npy',
#  '../input/spectrograms/noise/noisy_speech_1173..npy',
#  '../input/spectrograms/noise/noisy_speech_1522..npy',
#  '../input/spectrograms/noise/noisy_speech_1478..npy',
#  '../input/spectrograms/noise/noisy_speech_746..npy',
#  '../input/spectrograms/noise/noisy_speech_1289..npy',
#  '../input/spectrograms/noise/noisy_speech_261..npy',
#  '../input/spectrograms/noise/noisy_speech_1238..npy',
#  '../input/spectrograms/noise/noisy_speech_343..npy',
#  '../input/spectrograms/noise/noisy_speech_782..npy',
#  '../input/spectrograms/noise/noisy_speech_384..npy',
#  '../input/spectrograms/noise/noisy_speech_1059..npy',
#  '../input/spectrograms/noise/noisy_speech_795..npy',
#  '../input/spectrograms/noise/noisy_speech_1524..npy',
#  '../input/spectrograms/noise/noisy_speech_1648..npy',
#  '../input/spectrograms/noise/noisy_speech_1711..npy',
#  '../input/spectrograms/noise/noisy_speech_535..npy',
#  '../input/spectrograms/noise/noisy_speech_822..npy',
#  '../input/spectrograms/noise/noisy_speech_466..npy',
#  '../input/spectrograms/noise/noisy_speech_1975..npy',
#  '../input/spectrograms/noise/noisy_speech_2013..npy',
#  '../input/spectrograms/noise/noisy_speech_1870..npy',
#  '../input/spectrograms/noise/noisy_speech_1489..npy',
#  '../input/spectrograms/noise/noisy_speech_670..npy',
#  '../input/spectrograms/noise/noisy_speech_1679..npy',
#  '../input/spectrograms/noise/noisy_speech_883..npy',
#  '../input/spectrograms/noise/noisy_speech_860..npy',
#  '../input/spectrograms/noise/noisy_speech_827..npy',
#  '../input/spectrograms/noise/noisy_speech_1801..npy',
#  '../input/spectrograms/noise/noisy_speech_661..npy',
#  '../input/spectrograms/noise/noisy_speech_840..npy',
#  '../input/spectrograms/noise/noisy_speech_62..npy',
#  '../input/spectrograms/noise/noisy_speech_695..npy',
#  '../input/spectrograms/noise/noisy_speech_1770..npy',
#  '../input/spectrograms/noise/noisy_speech_524..npy',
#  '../input/spectrograms/noise/noisy_speech_152..npy',
#  '../input/spectrograms/noise/noisy_speech_1887..npy',
#  '../input/spectrograms/noise/noisy_speech_1635..npy',
#  '../input/spectrograms/noise/noisy_speech_1910..npy',
#  '../input/spectrograms/noise/noisy_speech_1233..npy',
#  '../input/spectrograms/noise/noisy_speech_341..npy',
#  '../input/spectrograms/noise/noisy_speech_1932..npy',
#  '../input/spectrograms/noise/noisy_speech_1214..npy',
#  '../input/spectrograms/noise/noisy_speech_904..npy',
#  '../input/spectrograms/noise/noisy_speech_32..npy',
#  '../input/spectrograms/noise/noisy_speech_357..npy',
#  '../input/spectrograms/noise/noisy_speech_1814..npy',
#  '../input/spectrograms/noise/noisy_speech_772..npy',
#  '../input/spectrograms/noise/noisy_speech_69..npy',
#  '../input/spectrograms/noise/noisy_speech_1327..npy',
#  '../input/spectrograms/noise/noisy_speech_629..npy',
#  '../input/spectrograms/noise/noisy_speech_918..npy',
#  '../input/spectrograms/noise/noisy_speech_546..npy',
#  '../input/spectrograms/noise/noisy_speech_294..npy',
#  '../input/spectrograms/noise/noisy_speech_1492..npy',
#  '../input/spectrograms/noise/noisy_speech_48..npy',
#  '../input/spectrograms/noise/noisy_speech_1062..npy',
#  '../input/spectrograms/noise/noisy_speech_50..npy',
#  '../input/spectrograms/noise/noisy_speech_1231..npy',
#  '../input/spectrograms/noise/noisy_speech_1044..npy',
#  '../input/spectrograms/noise/noisy_speech_1177..npy',
#  '../input/spectrograms/noise/noisy_speech_1852..npy',
#  '../input/spectrograms/noise/noisy_speech_1633..npy',
#  '../input/spectrograms/noise/noisy_speech_1298..npy',
#  '../input/spectrograms/noise/noisy_speech_414..npy',
#  '../input/spectrograms/noise/noisy_speech_1688..npy',
#  '../input/spectrograms/noise/noisy_speech_676..npy',
#  '../input/spectrograms/noise/noisy_speech_1799..npy',
#  '../input/spectrograms/noise/noisy_speech_1285..npy',
#  '../input/spectrograms/noise/noisy_speech_1473..npy',
#  '../input/spectrograms/noise/noisy_speech_740..npy',
#  '../input/spectrograms/noise/noisy_speech_290..npy',
#  '../input/spectrograms/noise/noisy_speech_1682..npy',
#  '../input/spectrograms/noise/noisy_speech_1382..npy',
#  '../input/spectrograms/noise/noisy_speech_1696..npy',
#  '../input/spectrograms/noise/noisy_speech_1551..npy',
#  '../input/spectrograms/noise/noisy_speech_1461..npy',
#  '../input/spectrograms/noise/noisy_speech_928..npy',
#  '../input/spectrograms/noise/noisy_speech_714..npy',
#  '../input/spectrograms/noise/noisy_speech_650..npy',
#  '../input/spectrograms/noise/noisy_speech_1659..npy',
#  '../input/spectrograms/noise/noisy_speech_1307..npy',
#  '../input/spectrograms/noise/noisy_speech_1503..npy',
#  '../input/spectrograms/noise/noisy_speech_306..npy',
#  '../input/spectrograms/noise/noisy_speech_1357..npy',
#  '../input/spectrograms/noise/noisy_speech_586..npy',
#  '../input/spectrograms/noise/noisy_speech_1261..npy',
#  '../input/spectrograms/noise/noisy_speech_46..npy',
#  '../input/spectrograms/noise/noisy_speech_842..npy',
#  '../input/spectrograms/noise/noisy_speech_1915..npy',
#  '../input/spectrograms/noise/noisy_speech_1125..npy',
#  '../input/spectrograms/noise/noisy_speech_1702..npy',
#  '../input/spectrograms/noise/noisy_speech_100..npy',
#  '../input/spectrograms/noise/noisy_speech_227..npy',
#  '../input/spectrograms/noise/noisy_speech_1303..npy',
#  '../input/spectrograms/noise/noisy_speech_655..npy',
#  '../input/spectrograms/noise/noisy_speech_1237..npy',
#  '../input/spectrograms/noise/noisy_speech_1337..npy',
#  '../input/spectrograms/noise/noisy_speech_270..npy',
#  '../input/spectrograms/noise/noisy_speech_1394..npy',
#  '../input/spectrograms/noise/noisy_speech_1242..npy',
#  '../input/spectrograms/noise/noisy_speech_1218..npy',
#  '../input/spectrograms/noise/noisy_speech_1978..npy',
#  '../input/spectrograms/noise/noisy_speech_385..npy',
#  '../input/spectrograms/noise/noisy_speech_962..npy',
#  '../input/spectrograms/noise/noisy_speech_1496..npy',
#  '../input/spectrograms/noise/noisy_speech_1372..npy',
#  '../input/spectrograms/noise/noisy_speech_1244..npy',
#  '../input/spectrograms/noise/noisy_speech_470..npy',
#  '../input/spectrograms/noise/noisy_speech_1223..npy',
#  '../input/spectrograms/noise/noisy_speech_1370..npy',
#  '../input/spectrograms/noise/noisy_speech_631..npy',
#  '../input/spectrograms/noise/noisy_speech_1278..npy',
#  '../input/spectrograms/noise/noisy_speech_1557..npy',
#  '../input/spectrograms/noise/noisy_speech_1545..npy',
#  '../input/spectrograms/noise/noisy_speech_1381..npy',
#  '../input/spectrograms/noise/noisy_speech_90..npy',
#  '../input/spectrograms/noise/noisy_speech_479..npy',
#  '../input/spectrograms/noise/noisy_speech_392..npy',
#  '../input/spectrograms/noise/noisy_speech_660..npy',
#  '../input/spectrograms/noise/noisy_speech_342..npy',
#  '../input/spectrograms/noise/noisy_speech_197..npy',
#  '../input/spectrograms/noise/noisy_speech_1535..npy',
#  '../input/spectrograms/noise/noisy_speech_1472..npy',
#  '../input/spectrograms/noise/noisy_speech_1549..npy',
#  '../input/spectrograms/noise/noisy_speech_163..npy',
#  '../input/spectrograms/noise/noisy_speech_1162..npy',
#  '../input/spectrograms/noise/noisy_speech_1151..npy',
#  '../input/spectrograms/noise/noisy_speech_1548..npy',
#  '../input/spectrograms/noise/noisy_speech_1572..npy',
#  '../input/spectrograms/noise/noisy_speech_901..npy',
#  '../input/spectrograms/noise/noisy_speech_823..npy',
#  '../input/spectrograms/noise/noisy_speech_284..npy',
#  '../input/spectrograms/noise/noisy_speech_1621..npy',
#  '../input/spectrograms/noise/noisy_speech_1243..npy',
#  '../input/spectrograms/noise/noisy_speech_593..npy',
#  '../input/spectrograms/noise/noisy_speech_376..npy',
#  '../input/spectrograms/noise/noisy_speech_2058..npy',
#  '../input/spectrograms/noise/noisy_speech_1332..npy',
#  '../input/spectrograms/noise/noisy_speech_1199..npy',
#  '../input/spectrograms/noise/noisy_speech_1701..npy',
#  '../input/spectrograms/noise/noisy_speech_758..npy',
#  '../input/spectrograms/noise/noisy_speech_421..npy',
#  '../input/spectrograms/noise/noisy_speech_1465..npy',
#  '../input/spectrograms/noise/noisy_speech_13..npy',
#  '../input/spectrograms/noise/noisy_speech_1813..npy',
#  '../input/spectrograms/noise/noisy_speech_44..npy',
#  '../input/spectrograms/noise/noisy_speech_1991..npy',
#  '../input/spectrograms/noise/noisy_speech_310..npy',
#  '../input/spectrograms/noise/noisy_speech_1011..npy',
#  '../input/spectrograms/noise/noisy_speech_1661..npy',
#  '../input/spectrograms/noise/noisy_speech_979..npy',
#  '../input/spectrograms/noise/noisy_speech_584..npy',
#  '../input/spectrograms/noise/noisy_speech_72..npy',
#  '../input/spectrograms/noise/noisy_speech_1511..npy',
#  '../input/spectrograms/noise/noisy_speech_975..npy',
#  '../input/spectrograms/noise/noisy_speech_1885..npy',
#  '../input/spectrograms/noise/noisy_speech_1417..npy',
#  '../input/spectrograms/noise/noisy_speech_355..npy',
#  '../input/spectrograms/noise/noisy_speech_1178..npy',
#  '../input/spectrograms/noise/noisy_speech_58..npy',
#  '../input/spectrograms/noise/noisy_speech_1995..npy',
#  '../input/spectrograms/noise/noisy_speech_783..npy',
#  '../input/spectrograms/noise/noisy_speech_36..npy',
#  '../input/spectrograms/noise/noisy_speech_583..npy',
#  '../input/spectrograms/noise/noisy_speech_1530..npy',
#  '../input/spectrograms/noise/noisy_speech_1707..npy',
#  '../input/spectrograms/noise/noisy_speech_454..npy',
#  '../input/spectrograms/noise/noisy_speech_946..npy',
#  '../input/spectrograms/noise/noisy_speech_39..npy',
#  '../input/spectrograms/noise/noisy_speech_1653..npy',
#  '../input/spectrograms/noise/noisy_speech_440..npy',
#  '../input/spectrograms/noise/noisy_speech_1037..npy',
#  '../input/spectrograms/noise/noisy_speech_1245..npy',
#  '../input/spectrograms/noise/noisy_speech_345..npy',
#  '../input/spectrograms/noise/noisy_speech_109..npy',
#  '../input/spectrograms/noise/noisy_speech_637..npy',
#  '../input/spectrograms/noise/noisy_speech_887..npy',
#  '../input/spectrograms/noise/noisy_speech_374..npy',
#  '../input/spectrograms/noise/noisy_speech_1095..npy',
#  '../input/spectrograms/noise/noisy_speech_1670..npy',
#  '../input/spectrograms/noise/noisy_speech_1446..npy',
#  '../input/spectrograms/noise/noisy_speech_990..npy',
#  '../input/spectrograms/noise/noisy_speech_86..npy',
#  '../input/spectrograms/noise/noisy_speech_1735..npy',
#  '../input/spectrograms/noise/noisy_speech_659..npy',
#  '../input/spectrograms/noise/noisy_speech_2041..npy',
#  '../input/spectrograms/noise/noisy_speech_809..npy',
#  '../input/spectrograms/noise/noisy_speech_1705..npy',
#  '../input/spectrograms/noise/noisy_speech_2034..npy',
#  '../input/spectrograms/noise/noisy_speech_1063..npy',
#  '../input/spectrograms/noise/noisy_speech_633..npy',
#  '../input/spectrograms/noise/noisy_speech_279..npy',
#  '../input/spectrograms/noise/noisy_speech_235..npy',
#  '../input/spectrograms/noise/noisy_speech_972..npy',
#  '../input/spectrograms/noise/noisy_speech_1431..npy',
#  '../input/spectrograms/noise/noisy_speech_820..npy',
#  '../input/spectrograms/noise/noisy_speech_1454..npy',
#  '../input/spectrograms/noise/noisy_speech_400..npy',
#  '../input/spectrograms/noise/noisy_speech_175..npy',
#  '../input/spectrograms/noise/noisy_speech_994..npy',
#  '../input/spectrograms/noise/noisy_speech_1751..npy',
#  '../input/spectrograms/noise/noisy_speech_1647..npy',
#  '../input/spectrograms/noise/noisy_speech_1842..npy',
#  '../input/spectrograms/noise/noisy_speech_1279..npy',
#  '../input/spectrograms/noise/noisy_speech_1809..npy',
#  '../input/spectrograms/noise/noisy_speech_1363..npy',
#  '../input/spectrograms/noise/noisy_speech_1792..npy',
#  '../input/spectrograms/noise/noisy_speech_1680..npy',
#  '../input/spectrograms/noise/noisy_speech_213..npy',
#  '../input/spectrograms/noise/noisy_speech_1277..npy',
#  '../input/spectrograms/noise/noisy_speech_1201..npy',
#  '../input/spectrograms/noise/noisy_speech_909..npy',
#  '../input/spectrograms/noise/noisy_speech_989..npy',
#  '../input/spectrograms/noise/noisy_speech_574..npy',
#  '../input/spectrograms/noise/noisy_speech_1965..npy',
#  '../input/spectrograms/noise/noisy_speech_721..npy',
#  '../input/spectrograms/noise/noisy_speech_1131..npy',
#  '../input/spectrograms/noise/noisy_speech_161..npy',
#  '../input/spectrograms/noise/noisy_speech_544..npy',
#  '../input/spectrograms/noise/noisy_speech_1812..npy',
#  '../input/spectrograms/noise/noisy_speech_1798..npy',
#  '../input/spectrograms/noise/noisy_speech_1817..npy',
#  '../input/spectrograms/noise/noisy_speech_1516..npy',
#  '../input/spectrograms/noise/noisy_speech_150..npy',
#  '../input/spectrograms/noise/noisy_speech_66..npy',
#  '../input/spectrograms/noise/noisy_speech_168..npy',
#  '../input/spectrograms/noise/noisy_speech_224..npy',
#  '../input/spectrograms/noise/noisy_speech_402..npy',
#  '../input/spectrograms/noise/noisy_speech_700..npy',
#  '../input/spectrograms/noise/noisy_speech_222..npy',
#  '../input/spectrograms/noise/noisy_speech_1149..npy',
#  '../input/spectrograms/noise/noisy_speech_494..npy',
#  '../input/spectrograms/noise/noisy_speech_1256..npy',
#  '../input/spectrograms/noise/noisy_speech_643..npy',
#  '../input/spectrograms/noise/noisy_speech_665..npy',
#  '../input/spectrograms/noise/noisy_speech_1564..npy',
#  '../input/spectrograms/noise/noisy_speech_1537..npy',
#  '../input/spectrograms/noise/noisy_speech_696..npy',
#  '../input/spectrograms/noise/noisy_speech_178..npy',
#  '../input/spectrograms/noise/noisy_speech_673..npy',
#  '../input/spectrograms/noise/noisy_speech_627..npy',
#  '../input/spectrograms/noise/noisy_speech_1980..npy',
#  '../input/spectrograms/noise/noisy_speech_293..npy',
#  '../input/spectrograms/noise/noisy_speech_1828..npy',
#  '../input/spectrograms/noise/noisy_speech_1886..npy',
#  '../input/spectrograms/noise/noisy_speech_196..npy',
#  '../input/spectrograms/noise/noisy_speech_27..npy',
#  '../input/spectrograms/noise/noisy_speech_1904..npy',
#  '../input/spectrograms/noise/noisy_speech_1547..npy',
#  '../input/spectrograms/noise/noisy_speech_1984..npy',
#  '../input/spectrograms/noise/noisy_speech_1778..npy',
#  '../input/spectrograms/noise/noisy_speech_476..npy',
#  '../input/spectrograms/noise/noisy_speech_1727..npy',
#  '../input/spectrograms/noise/noisy_speech_497..npy',
#  '../input/spectrograms/noise/noisy_speech_1442..npy',
#  '../input/spectrograms/noise/noisy_speech_378..npy',
#  '../input/spectrograms/noise/noisy_speech_1248..npy',
#  '../input/spectrograms/noise/noisy_speech_874..npy',
#  '../input/spectrograms/noise/noisy_speech_1320..npy',
#  '../input/spectrograms/noise/noisy_speech_2045..npy',
#  '../input/spectrograms/noise/noisy_speech_1210..npy',
#  '../input/spectrograms/noise/noisy_speech_1495..npy',
#  '../input/spectrograms/noise/noisy_speech_893..npy',
#  '../input/spectrograms/noise/noisy_speech_188..npy',
#  '../input/spectrograms/noise/noisy_speech_1186..npy',
#  '../input/spectrograms/noise/noisy_speech_441..npy',
#  '../input/spectrograms/noise/noisy_speech_602..npy',
#  '../input/spectrograms/noise/noisy_speech_1050..npy',
#  '../input/spectrograms/noise/noisy_speech_1567..npy',
#  '../input/spectrograms/noise/noisy_speech_624..npy',
#  '../input/spectrograms/noise/noisy_speech_886..npy',
#  '../input/spectrograms/noise/noisy_speech_618..npy',
#  '../input/spectrograms/noise/noisy_speech_1325..npy',
#  '../input/spectrograms/noise/noisy_speech_1453..npy',
#  '../input/spectrograms/noise/noisy_speech_379..npy',
#  '../input/spectrograms/noise/noisy_speech_391..npy',
#  '../input/spectrograms/noise/noisy_speech_642..npy',
#  '../input/spectrograms/noise/noisy_speech_280..npy',
#  '../input/spectrograms/noise/noisy_speech_1822..npy',
#  '../input/spectrograms/noise/noisy_speech_1941..npy',
#  '../input/spectrograms/noise/noisy_speech_1797..npy',
#  '../input/spectrograms/noise/noisy_speech_1104..npy',
#  '../input/spectrograms/noise/noisy_speech_31..npy',
#  '../input/spectrograms/noise/noisy_speech_1634..npy',
#  '../input/spectrograms/noise/noisy_speech_1745..npy',
#  '../input/spectrograms/noise/noisy_speech_1469..npy',
#  '../input/spectrograms/noise/noisy_speech_853..npy',
#  '../input/spectrograms/noise/noisy_speech_1460..npy',
#  '../input/spectrograms/noise/noisy_speech_1071..npy',
#  '../input/spectrograms/noise/noisy_speech_995..npy',
#  '../input/spectrograms/noise/noisy_speech_1923..npy',
#  '../input/spectrograms/noise/noisy_speech_1960..npy',
#  '../input/spectrograms/noise/noisy_speech_1340..npy',
#  '../input/spectrograms/noise/noisy_speech_2022..npy',
#  '../input/spectrograms/noise/noisy_speech_859..npy',
#  '../input/spectrograms/noise/noisy_speech_1074..npy',
#  '../input/spectrograms/noise/noisy_speech_915..npy',
#  '../input/spectrograms/noise/noisy_speech_1603..npy',
#  '../input/spectrograms/noise/noisy_speech_1295..npy',
#  '../input/spectrograms/noise/noisy_speech_1003..npy',
#  '../input/spectrograms/noise/noisy_speech_1725..npy',
#  '../input/spectrograms/noise/noisy_speech_1867..npy',
#  '../input/spectrograms/noise/noisy_speech_921..npy',
#  '../input/spectrograms/noise/noisy_speech_77..npy',
#  '../input/spectrograms/noise/noisy_speech_1404..npy',
#  '../input/spectrograms/noise/noisy_speech_144..npy',
#  '../input/spectrograms/noise/noisy_speech_530..npy',
#  '../input/spectrograms/noise/noisy_speech_1257..npy',
#  '../input/spectrograms/noise/noisy_speech_542..npy',
#  '../input/spectrograms/noise/noisy_speech_1077..npy',
#  '../input/spectrograms/noise/noisy_speech_423..npy',
#  '../input/spectrograms/noise/noisy_speech_316..npy',
#  '../input/spectrograms/noise/noisy_speech_1687..npy',
#  '../input/spectrograms/noise/noisy_speech_1781..npy',
#  '../input/spectrograms/noise/noisy_speech_735..npy',
#  '../input/spectrograms/noise/noisy_speech_417..npy',
#  '../input/spectrograms/noise/noisy_speech_462..npy',
#  '../input/spectrograms/noise/noisy_speech_190..npy',
#  '../input/spectrograms/noise/noisy_speech_771..npy',
#  '../input/spectrograms/noise/noisy_speech_687..npy',
#  '../input/spectrograms/noise/noisy_speech_1293..npy',
#  '../input/spectrograms/noise/noisy_speech_1397..npy',
#  '../input/spectrograms/noise/noisy_speech_553..npy',
#  '../input/spectrograms/noise/noisy_speech_997..npy',
#  '../input/spectrograms/noise/noisy_speech_1903..npy',
#  '../input/spectrograms/noise/noisy_speech_192..npy',
#  '../input/spectrograms/noise/noisy_speech_1158..npy',
#  '../input/spectrograms/noise/noisy_speech_425..npy',
#  '../input/spectrograms/noise/noisy_speech_588..npy',
#  '../input/spectrograms/noise/noisy_speech_1076..npy',
#  '../input/spectrograms/noise/noisy_speech_463..npy',
#  '../input/spectrograms/noise/noisy_speech_924..npy',
#  '../input/spectrograms/noise/noisy_speech_141..npy',
#  '../input/spectrograms/noise/noisy_speech_856..npy',
#  '../input/spectrograms/noise/noisy_speech_1047..npy',
#  '../input/spectrograms/noise/noisy_speech_55..npy',
#  '../input/spectrograms/noise/noisy_speech_1578..npy',
#  '../input/spectrograms/noise/noisy_speech_1608..npy',
#  '../input/spectrograms/noise/noisy_speech_1198..npy',
#  '../input/spectrograms/noise/noisy_speech_110..npy',
#  '../input/spectrograms/noise/noisy_speech_252..npy',
#  '../input/spectrograms/noise/noisy_speech_311..npy',
#  '../input/spectrograms/noise/noisy_speech_656..npy',
#  '../input/spectrograms/noise/noisy_speech_1155..npy',
#  '../input/spectrograms/noise/noisy_speech_1949..npy',
#  '../input/spectrograms/noise/noisy_speech_1529..npy',
#  '../input/spectrograms/noise/noisy_speech_1811..npy',
#  '../input/spectrograms/noise/noisy_speech_601..npy',
#  '../input/spectrograms/noise/noisy_speech_1014..npy',
#  '../input/spectrograms/noise/noisy_speech_138..npy',
#  '../input/spectrograms/noise/noisy_speech_399..npy',
#  '../input/spectrograms/noise/noisy_speech_1255..npy',
#  '../input/spectrograms/noise/noisy_speech_623..npy',
#  '../input/spectrograms/noise/noisy_speech_1384..npy',
#  '../input/spectrograms/noise/noisy_speech_844..npy',
#  '../input/spectrograms/noise/noisy_speech_173..npy',
#  '../input/spectrograms/noise/noisy_speech_1600..npy',
#  '../input/spectrograms/noise/noisy_speech_1026..npy',
#  '../input/spectrograms/noise/noisy_speech_336..npy',
#  '../input/spectrograms/noise/noisy_speech_1649..npy',
#  '../input/spectrograms/noise/noisy_speech_210..npy',
#  '../input/spectrograms/noise/noisy_speech_1191..npy',
#  '../input/spectrograms/noise/noisy_speech_360..npy',
#  '../input/spectrograms/noise/noisy_speech_434..npy',
#  '../input/spectrograms/noise/noisy_speech_829..npy',
#  '../input/spectrograms/noise/noisy_speech_1292..npy',
#  '../input/spectrograms/noise/noisy_speech_1502..npy',
#  '../input/spectrograms/noise/noisy_speech_2047..npy',
#  '../input/spectrograms/noise/noisy_speech_1629..npy',
#  '../input/spectrograms/noise/noisy_speech_199..npy',
#  '../input/spectrograms/noise/noisy_speech_255..npy',
#  '../input/spectrograms/noise/noisy_speech_1305..npy',
#  '../input/spectrograms/noise/noisy_speech_1565..npy',
#  '../input/spectrograms/noise/noisy_speech_1130..npy',
#  '../input/spectrograms/noise/noisy_speech_315..npy',
#  '../input/spectrograms/noise/noisy_speech_1322..npy',
#  '../input/spectrograms/noise/noisy_speech_1073..npy',
#  '../input/spectrograms/noise/noisy_speech_1041..npy',
#  '../input/spectrograms/noise/noisy_speech_142..npy',
#  '../input/spectrograms/noise/noisy_speech_1138..npy',
#  '../input/spectrograms/noise/noisy_speech_891..npy',
#  '../input/spectrograms/noise/noisy_speech_340..npy',
#  '../input/spectrograms/noise/noisy_speech_804..npy',
#  '../input/spectrograms/noise/noisy_speech_456..npy',
#  '../input/spectrograms/noise/noisy_speech_313..npy',
#  '../input/spectrograms/noise/noisy_speech_667..npy',
#  '../input/spectrograms/noise/noisy_speech_1449..npy',
#  '../input/spectrograms/noise/noisy_speech_794..npy',
#  '../input/spectrograms/noise/noisy_speech_116..npy',
#  '../input/spectrograms/noise/noisy_speech_540..npy',
#  '../input/spectrograms/noise/noisy_speech_786..npy',
#  '../input/spectrograms/noise/noisy_speech_465..npy',
#  '../input/spectrograms/noise/noisy_speech_653..npy',
#  '../input/spectrograms/noise/noisy_speech_386..npy',
#  '../input/spectrograms/noise/noisy_speech_657..npy',
#  '../input/spectrograms/noise/noisy_speech_1474..npy',
#  '../input/spectrograms/noise/noisy_speech_131..npy',
#  '../input/spectrograms/noise/noisy_speech_509..npy',
#  '../input/spectrograms/noise/noisy_speech_981..npy',
#  '../input/spectrograms/noise/noisy_speech_969..npy',
#  '../input/spectrograms/noise/noisy_speech_1345..npy',
#  '../input/spectrograms/noise/noisy_speech_1832..npy',
#  '../input/spectrograms/noise/noisy_speech_9..npy',
#  '../input/spectrograms/noise/noisy_speech_154..npy',
#  '../input/spectrograms/noise/noisy_speech_504..npy',
#  '../input/spectrograms/noise/noisy_speech_1217..npy',
#  '../input/spectrograms/noise/noisy_speech_415..npy',
#  '../input/spectrograms/noise/noisy_speech_1720..npy',
#  '../input/spectrograms/noise/noisy_speech_2004..npy',
#  '../input/spectrograms/noise/noisy_speech_525..npy',
#  '../input/spectrograms/noise/noisy_speech_128..npy',
#  '../input/spectrograms/noise/noisy_speech_1390..npy',
#  '../input/spectrograms/noise/noisy_speech_923..npy',
#  '../input/spectrograms/noise/noisy_speech_705..npy',
#  '../input/spectrograms/noise/noisy_speech_1276..npy',
#  '../input/spectrograms/noise/noisy_speech_1386..npy',
#  '../input/spectrograms/noise/noisy_speech_1593..npy',
#  '../input/spectrograms/noise/noisy_speech_1331..npy',
#  '../input/spectrograms/noise/noisy_speech_1508..npy',
#  '../input/spectrograms/noise/noisy_speech_677..npy',
#  '../input/spectrograms/noise/noisy_speech_1938..npy',
#  '../input/spectrograms/noise/noisy_speech_1740..npy',
#  '../input/spectrograms/noise/noisy_speech_1161..npy',
#  '../input/spectrograms/noise/noisy_speech_1848..npy',
#  '../input/spectrograms/noise/noisy_speech_1558..npy',
#  '../input/spectrograms/noise/noisy_speech_18..npy',
#  '../input/spectrograms/noise/noisy_speech_258..npy',
#  '../input/spectrograms/noise/noisy_speech_1976..npy',
#  '../input/spectrograms/noise/noisy_speech_1730..npy',
#  '../input/spectrograms/noise/noisy_speech_475..npy',
#  '../input/spectrograms/noise/noisy_speech_868..npy',
#  '../input/spectrograms/noise/noisy_speech_548..npy',
#  '../input/spectrograms/noise/noisy_speech_201..npy',
#  '../input/spectrograms/noise/noisy_speech_1265..npy',
#  '../input/spectrograms/noise/noisy_speech_1883..npy',
#  '../input/spectrograms/noise/noisy_speech_1413..npy',
#  '../input/spectrograms/noise/noisy_speech_361..npy',
#  '../input/spectrograms/noise/noisy_speech_243..npy',
#  '../input/spectrograms/noise/noisy_speech_1338..npy',
#  '../input/spectrograms/noise/noisy_speech_1717..npy',
#  '../input/spectrograms/noise/noisy_speech_354..npy',
#  '../input/spectrograms/noise/noisy_speech_1093..npy',
#  '../input/spectrograms/noise/noisy_speech_1111..npy',
#  '../input/spectrograms/noise/noisy_speech_739..npy',
#  '../input/spectrograms/noise/noisy_speech_865..npy',
#  '../input/spectrograms/noise/noisy_speech_697..npy',
#  '../input/spectrograms/noise/noisy_speech_370..npy',
#  '../input/spectrograms/noise/noisy_speech_1318..npy',
#  '../input/spectrograms/noise/noisy_speech_99..npy',
#  '../input/spectrograms/noise/noisy_speech_1612..npy',
#  '../input/spectrograms/noise/noisy_speech_1899..npy',
#  '../input/spectrograms/noise/noisy_speech_541..npy',
#  '../input/spectrograms/noise/noisy_speech_1853..npy',
#  '../input/spectrograms/noise/noisy_speech_1187..npy',
#  '../input/spectrograms/noise/noisy_speech_1866..npy',
#  '../input/spectrograms/noise/noisy_speech_1124..npy',
#  '../input/spectrograms/noise/noisy_speech_49..npy',
#  '../input/spectrograms/noise/noisy_speech_785..npy',
#  '../input/spectrograms/noise/noisy_speech_1999..npy',
#  '../input/spectrograms/noise/noisy_speech_615..npy',
#  '../input/spectrograms/noise/noisy_speech_561..npy',
#  '../input/spectrograms/noise/noisy_speech_183..npy',
#  '../input/spectrograms/noise/noisy_speech_798..npy',
#  '../input/spectrograms/noise/noisy_speech_1639..npy',
#  '../input/spectrograms/noise/noisy_speech_327..npy',
#  '../input/spectrograms/noise/noisy_speech_1846..npy',
#  '../input/spectrograms/noise/noisy_speech_715..npy',
#  '../input/spectrograms/noise/noisy_speech_272..npy',
#  '../input/spectrograms/noise/noisy_speech_1841..npy',
#  '../input/spectrograms/noise/noisy_speech_1007..npy',
#  '../input/spectrograms/noise/noisy_speech_797..npy',
#  '../input/spectrograms/noise/noisy_speech_2057..npy',
#  '../input/spectrograms/noise/noisy_speech_1252..npy',
#  '../input/spectrograms/noise/noisy_speech_1728..npy',
#  '../input/spectrograms/noise/noisy_speech_686..npy',
#  '../input/spectrograms/noise/noisy_speech_1260..npy',
#  '../input/spectrograms/noise/noisy_speech_1678..npy',
#  '../input/spectrograms/noise/noisy_speech_1562..npy',
#  '../input/spectrograms/noise/noisy_speech_42..npy',
#  '../input/spectrograms/noise/noisy_speech_1843..npy',
#  '../input/spectrograms/noise/noisy_speech_1114..npy',
#  '../input/spectrograms/noise/noisy_speech_242..npy',
#  '../input/spectrograms/noise/noisy_speech_1758..npy',
#  '../input/spectrograms/noise/noisy_speech_129..npy',
#  '../input/spectrograms/noise/noisy_speech_516..npy',
#  '../input/spectrograms/noise/noisy_speech_832..npy',
#  '../input/spectrograms/noise/noisy_speech_1929..npy',
#  '../input/spectrograms/noise/noisy_speech_890..npy',
#  '../input/spectrograms/noise/noisy_speech_1847..npy',
#  '../input/spectrograms/noise/noisy_speech_1854..npy',
#  '../input/spectrograms/noise/noisy_speech_1624..npy',
#  '../input/spectrograms/noise/noisy_speech_1192..npy',
#  '../input/spectrograms/noise/noisy_speech_980..npy',
#  '../input/spectrograms/noise/noisy_speech_780..npy',
#  '../input/spectrograms/noise/noisy_speech_322..npy',
#  '../input/spectrograms/noise/noisy_speech_1140..npy',
#  '../input/spectrograms/noise/noisy_speech_283..npy',
#  '../input/spectrograms/noise/noisy_speech_988..npy',
#  '../input/spectrograms/noise/noisy_speech_1954..npy',
#  '../input/spectrograms/noise/noisy_speech_1875..npy',
#  '../input/spectrograms/noise/noisy_speech_1756..npy',
#  '../input/spectrograms/noise/noisy_speech_157..npy',
#  '../input/spectrograms/noise/noisy_speech_1463..npy',
#  '../input/spectrograms/noise/noisy_speech_481..npy',
#  '../input/spectrograms/noise/noisy_speech_567..npy',
#  '../input/spectrograms/noise/noisy_speech_1536..npy',
#  '../input/spectrograms/noise/noisy_speech_1174..npy',
#  '../input/spectrograms/noise/noisy_speech_679..npy',
#  '../input/spectrograms/noise/noisy_speech_393..npy',
#  '../input/spectrograms/noise/noisy_speech_1368..npy',
#  '../input/spectrograms/noise/noisy_speech_1085..npy',
#  '../input/spectrograms/noise/noisy_speech_1395..npy',
#  '../input/spectrograms/noise/noisy_speech_1493..npy',
#  '../input/spectrograms/noise/noisy_speech_1139..npy',
#  '../input/spectrograms/noise/noisy_speech_1376..npy',
#  '../input/spectrograms/noise/noisy_speech_1829..npy',
#  '../input/spectrograms/noise/noisy_speech_831..npy',
#  '../input/spectrograms/noise/noisy_speech_1428..npy',
#  '../input/spectrograms/noise/noisy_speech_882..npy',
#  '../input/spectrograms/noise/noisy_speech_160..npy',
#  '../input/spectrograms/noise/noisy_speech_198..npy',
#  '../input/spectrograms/noise/noisy_speech_939..npy',
#  '../input/spectrograms/noise/noisy_speech_359..npy',
#  '../input/spectrograms/noise/noisy_speech_1400..npy',
#  '../input/spectrograms/noise/noisy_speech_1497..npy',
#  '../input/spectrograms/noise/noisy_speech_1159..npy',
#  '../input/spectrograms/noise/noisy_speech_135..npy',
#  '../input/spectrograms/noise/noisy_speech_1519..npy',
#  '../input/spectrograms/noise/noisy_speech_1992..npy',
#  '../input/spectrograms/noise/noisy_speech_74..npy',
#  '../input/spectrograms/noise/noisy_speech_1868..npy',
#  '../input/spectrograms/noise/noisy_speech_346..npy',
#  '../input/spectrograms/noise/noisy_speech_1951..npy',
#  '../input/spectrograms/noise/noisy_speech_68..npy',
#  '../input/spectrograms/noise/noisy_speech_1880..npy',
#  '../input/spectrograms/noise/noisy_speech_1737..npy',
#  '../input/spectrograms/noise/noisy_speech_595..npy',
#  '../input/spectrograms/noise/noisy_speech_852..npy',
#  '../input/spectrograms/noise/noisy_speech_621..npy',
#  '../input/spectrograms/noise/noisy_speech_841..npy',
#  '../input/spectrograms/noise/noisy_speech_1597..npy',
#  '../input/spectrograms/noise/noisy_speech_1126..npy',
#  '../input/spectrograms/noise/noisy_speech_563..npy',
#  '../input/spectrograms/noise/noisy_speech_482..npy',
#  '../input/spectrograms/noise/noisy_speech_1777..npy',
#  '../input/spectrograms/noise/noisy_speech_1378..npy',
#  '../input/spectrograms/noise/noisy_speech_1571..npy',
#  '../input/spectrograms/noise/noisy_speech_461..npy',
#  '../input/spectrograms/noise/noisy_speech_1718..npy',
#  '../input/spectrograms/noise/noisy_speech_2003..npy',
#  '../input/spectrograms/noise/noisy_speech_1552..npy',
#  '../input/spectrograms/noise/noisy_speech_1263..npy',
#  '../input/spectrograms/noise/noisy_speech_1902..npy',
#  '../input/spectrograms/noise/noisy_speech_1908..npy',
#  '../input/spectrograms/noise/noisy_speech_927..npy',
#  '../input/spectrograms/noise/noisy_speech_1078..npy',
#  '../input/spectrograms/noise/noisy_speech_1035..npy',
#  '../input/spectrograms/noise/noisy_speech_845..npy',
#  '../input/spectrograms/noise/noisy_speech_957..npy',
#  '../input/spectrograms/noise/noisy_speech_1116..npy',
#  '../input/spectrograms/noise/noisy_speech_1950..npy',
#  '../input/spectrograms/noise/noisy_speech_1367..npy',
#  '../input/spectrograms/noise/noisy_speech_2006..npy',
#  '../input/spectrograms/noise/noisy_speech_881..npy',
#  '../input/spectrograms/noise/noisy_speech_40..npy',
#  '../input/spectrograms/noise/noisy_speech_547..npy',
#  '../input/spectrograms/noise/noisy_speech_1146..npy',
#  '../input/spectrograms/noise/noisy_speech_1650..npy',
#  '../input/spectrograms/noise/noisy_speech_126..npy',
#  '../input/spectrograms/noise/noisy_speech_626..npy',
#  '../input/spectrograms/noise/noisy_speech_884..npy',
#  '../input/spectrograms/noise/noisy_speech_922..npy',
#  '../input/spectrograms/noise/noisy_speech_733..npy',
#  '../input/spectrograms/noise/noisy_speech_416..npy',
#  '../input/spectrograms/noise/noisy_speech_17..npy',
#  '../input/spectrograms/noise/noisy_speech_1754..npy',
#  '../input/spectrograms/noise/noisy_speech_1311..npy',
#  '../input/spectrograms/noise/noisy_speech_967..npy',
#  '../input/spectrograms/noise/noisy_speech_1512..npy',
#  '../input/spectrograms/noise/noisy_speech_1824..npy',
#  '../input/spectrograms/noise/noisy_speech_1935..npy',
#  '../input/spectrograms/noise/noisy_speech_911..npy',
#  '../input/spectrograms/noise/noisy_speech_628..npy',
#  '../input/spectrograms/noise/noisy_speech_630..npy',
#  '../input/spectrograms/noise/noisy_speech_1894..npy',
#  '../input/spectrograms/noise/noisy_speech_375..npy',
#  '../input/spectrograms/noise/noisy_speech_871..npy',
#  '../input/spectrograms/noise/noisy_speech_1120..npy',
#  '../input/spectrograms/noise/noisy_speech_1410..npy',
#  '../input/spectrograms/noise/noisy_speech_1336..npy',
#  '../input/spectrograms/noise/noisy_speech_800..npy',
#  '../input/spectrograms/noise/noisy_speech_1299..npy',
#  '../input/spectrograms/noise/noisy_speech_365..npy',
#  '../input/spectrograms/noise/noisy_speech_510..npy',
#  '../input/spectrograms/noise/noisy_speech_947..npy',
#  '../input/spectrograms/noise/noisy_speech_897..npy',
#  '../input/spectrograms/noise/noisy_speech_1818..npy',
#  '../input/spectrograms/noise/noisy_speech_953..npy',
#  '../input/spectrograms/noise/noisy_speech_2059..npy',
#  '../input/spectrograms/noise/noisy_speech_1294..npy',
#  '../input/spectrograms/noise/noisy_speech_817..npy',
#  '../input/spectrograms/noise/noisy_speech_1009..npy',
#  '../input/spectrograms/noise/noisy_speech_950..npy',
#  '../input/spectrograms/noise/noisy_speech_1152..npy',
#  '../input/spectrograms/noise/noisy_speech_1232..npy',
#  '../input/spectrograms/noise/noisy_speech_968..npy',
#  '../input/spectrograms/noise/noisy_speech_464..npy',
#  '../input/spectrograms/noise/noisy_speech_181..npy',
#  '../input/spectrograms/noise/noisy_speech_1230..npy',
#  '../input/spectrograms/noise/noisy_speech_1759..npy',
#  '../input/spectrograms/noise/noisy_speech_1122..npy',
#  '../input/spectrograms/noise/noisy_speech_1286..npy',
#  '../input/spectrograms/noise/noisy_speech_572..npy',
#  '../input/spectrograms/noise/noisy_speech_299..npy',
#  '../input/spectrograms/noise/noisy_speech_244..npy',
#  '../input/spectrograms/noise/noisy_speech_1500..npy',
#  '../input/spectrograms/noise/noisy_speech_1123..npy',
#  '../input/spectrograms/noise/noisy_speech_767..npy',
#  '../input/spectrograms/noise/noisy_speech_1477..npy',
#  '../input/spectrograms/noise/noisy_speech_120..npy',
#  '../input/spectrograms/noise/noisy_speech_165..npy',
#  '../input/spectrograms/noise/noisy_speech_75..npy',
#  '../input/spectrograms/noise/noisy_speech_1291..npy',
#  '../input/spectrograms/noise/noisy_speech_323..npy',
#  '../input/spectrograms/noise/noisy_speech_2017..npy',
#  '../input/spectrograms/noise/noisy_speech_1641..npy',
#  '../input/spectrograms/noise/noisy_speech_1760..npy',
#  '../input/spectrograms/noise/noisy_speech_1172..npy',
#  '../input/spectrograms/noise/noisy_speech_1514..npy',
#  '../input/spectrograms/noise/noisy_speech_1850..npy',
#  '../input/spectrograms/noise/noisy_speech_1451..npy',
#  '../input/spectrograms/noise/noisy_speech_24..npy',
#  '../input/spectrograms/noise/noisy_speech_231..npy',
#  '../input/spectrograms/noise/noisy_speech_815..npy',
#  '../input/spectrograms/noise/noisy_speech_1000..npy',
#  '../input/spectrograms/noise/noisy_speech_219..npy',
#  '../input/spectrograms/noise/noisy_speech_1419..npy',
#  '../input/spectrograms/noise/noisy_speech_1002..npy',
#  '../input/spectrograms/noise/noisy_speech_429..npy',
#  '../input/spectrograms/noise/noisy_speech_1491..npy',
#  '../input/spectrograms/noise/noisy_speech_1203..npy',
#  '../input/spectrograms/noise/noisy_speech_1956..npy',
#  '../input/spectrograms/noise/noisy_speech_1487..npy',
#  '../input/spectrograms/noise/noisy_speech_1216..npy',
#  '../input/spectrograms/noise/noisy_speech_1807..npy',
#  '../input/spectrograms/noise/noisy_speech_380..npy',
#  '../input/spectrograms/noise/noisy_speech_257..npy',
#  '../input/spectrograms/noise/noisy_speech_2021..npy',
#  '../input/spectrograms/noise/noisy_speech_1757..npy',
#  '../input/spectrograms/noise/noisy_speech_472..npy',
#  '../input/spectrograms/noise/noisy_speech_747..npy',
#  '../input/spectrograms/noise/noisy_speech_1247..npy',
#  '../input/spectrograms/noise/noisy_speech_1594..npy',
#  '../input/spectrograms/noise/noisy_speech_838..npy',
#  '../input/spectrograms/noise/noisy_speech_1281..npy',
#  '../input/spectrograms/noise/noisy_speech_1620..npy',
#  '../input/spectrograms/noise/noisy_speech_551..npy',
#  '../input/spectrograms/noise/noisy_speech_1380..npy',
#  '../input/spectrograms/noise/noisy_speech_1533..npy',
#  '../input/spectrograms/noise/noisy_speech_982..npy',
#  '../input/spectrograms/noise/noisy_speech_1559..npy',
#  '../input/spectrograms/noise/noisy_speech_238..npy',
#  '../input/spectrograms/noise/noisy_speech_353..npy',
#  '../input/spectrograms/noise/noisy_speech_1202..npy',
#  '../input/spectrograms/noise/noisy_speech_2051..npy',
#  '../input/spectrograms/noise/noisy_speech_388..npy',
#  '../input/spectrograms/noise/noisy_speech_523..npy',
#  '../input/spectrograms/noise/noisy_speech_1058..npy',
#  '../input/spectrograms/noise/noisy_speech_102..npy',
#  '../input/spectrograms/noise/noisy_speech_1128..npy',
#  '../input/spectrograms/noise/noisy_speech_1481..npy',
#  '../input/spectrograms/noise/noisy_speech_1729..npy',
#  '../input/spectrograms/noise/noisy_speech_321..npy',
#  '../input/spectrograms/noise/noisy_speech_1075..npy',
#  '../input/spectrograms/noise/noisy_speech_4..npy',
#  '../input/spectrograms/noise/noisy_speech_319..npy',
#  '../input/spectrograms/noise/noisy_speech_2007..npy',
#  '../input/spectrograms/noise/noisy_speech_833..npy',
#  '../input/spectrograms/noise/noisy_speech_846..npy',
#  '../input/spectrograms/noise/noisy_speech_427..npy',
#  '../input/spectrograms/noise/noisy_speech_892..npy',
#  '../input/spectrograms/noise/noisy_speech_1324..npy',
#  '../input/spectrograms/noise/noisy_speech_65..npy',
#  '../input/spectrograms/noise/noisy_speech_35..npy',
#  '../input/spectrograms/noise/noisy_speech_1922..npy',
#  '../input/spectrograms/noise/noisy_speech_1926..npy',
#  '../input/spectrograms/noise/noisy_speech_281..npy',
#  '../input/spectrograms/noise/noisy_speech_41..npy',
#  '../input/spectrograms/noise/noisy_speech_480..npy',
#  '../input/spectrograms/noise/noisy_speech_1598..npy',
#  '../input/spectrograms/noise/noisy_speech_1326..npy',
#  '../input/spectrograms/noise/noisy_speech_1068..npy',
#  '../input/spectrograms/noise/noisy_speech_1022..npy',
#  '../input/spectrograms/noise/noisy_speech_489..npy',
#  '../input/spectrograms/noise/noisy_speech_1471..npy',
#  '../input/spectrograms/noise/noisy_speech_861..npy',
#  '../input/spectrograms/noise/noisy_speech_1048..npy',
#  '../input/spectrograms/noise/noisy_speech_1573..npy',
#  '../input/spectrograms/noise/noisy_speech_1270..npy',
#  '../input/spectrograms/noise/noisy_speech_1645..npy',
#  '../input/spectrograms/noise/noisy_speech_1560..npy',
#  '../input/spectrograms/noise/noisy_speech_1004..npy',
#  '../input/spectrograms/noise/noisy_speech_1721..npy',
#  '../input/spectrograms/noise/noisy_speech_1943..npy',
#  '../input/spectrograms/noise/noisy_speech_1300..npy',
#  '../input/spectrograms/noise/noisy_speech_1040..npy',
#  '../input/spectrograms/noise/noisy_speech_53..npy',
#  '../input/spectrograms/noise/noisy_speech_1094..npy',
#  '../input/spectrograms/noise/noisy_speech_1312..npy',
#  '../input/spectrograms/noise/noisy_speech_1970..npy',
#  '../input/spectrograms/noise/noisy_speech_1212..npy',
#  '../input/spectrograms/noise/noisy_speech_1190..npy',
#  '../input/spectrograms/noise/noisy_speech_88..npy',
#  '../input/spectrograms/noise/noisy_speech_367..npy',
#  '../input/spectrograms/noise/noisy_speech_1712..npy',
#  '../input/spectrograms/noise/noisy_speech_1986..npy',
#  '../input/spectrograms/noise/noisy_speech_246..npy',
#  '../input/spectrograms/noise/noisy_speech_2056..npy',
#  '../input/spectrograms/noise/noisy_speech_622..npy',
#  '../input/spectrograms/noise/noisy_speech_707..npy',
#  '../input/spectrograms/noise/noisy_speech_147..npy',
#  '../input/spectrograms/noise/noisy_speech_1207..npy',
#  '../input/spectrograms/noise/noisy_speech_1579..npy',
#  '../input/spectrograms/noise/noisy_speech_555..npy',
#  '../input/spectrograms/noise/noisy_speech_1479..npy',
#  '../input/spectrograms/noise/noisy_speech_556..npy',
#  '../input/spectrograms/noise/noisy_speech_1541..npy',
#  '../input/spectrograms/noise/noisy_speech_274..npy',
#  '../input/spectrograms/noise/noisy_speech_1966..npy',
#  '../input/spectrograms/noise/noisy_speech_363..npy',
#  '../input/spectrograms/noise/noisy_speech_1052..npy',
#  '../input/spectrograms/noise/noisy_speech_324..npy',
#  '../input/spectrograms/noise/noisy_speech_1081..npy',
#  '../input/spectrograms/noise/noisy_speech_1599..npy',
#  '../input/spectrograms/noise/noisy_speech_1250..npy',
#  '../input/spectrograms/noise/noisy_speech_644..npy',
#  '../input/spectrograms/noise/noisy_speech_1321..npy',
#  '../input/spectrograms/noise/noisy_speech_2061..npy',
#  '../input/spectrograms/noise/noisy_speech_237..npy',
#  '../input/spectrograms/noise/noisy_speech_1761..npy',
#  '../input/spectrograms/noise/noisy_speech_751..npy',
#  '../input/spectrograms/noise/noisy_speech_1098..npy',
#  '../input/spectrograms/noise/noisy_speech_1036..npy',
#  '../input/spectrograms/noise/noisy_speech_1110..npy',
#  '../input/spectrograms/noise/noisy_speech_1182..npy',
#  '../input/spectrograms/noise/noisy_speech_1045..npy',
#  '../input/spectrograms/noise/noisy_speech_149..npy',
#  '../input/spectrograms/noise/noisy_speech_106..npy',
#  '../input/spectrograms/noise/noisy_speech_207..npy',
#  '../input/spectrograms/noise/noisy_speech_591..npy',
#  '../input/spectrograms/noise/noisy_speech_1163..npy',
#  '../input/spectrograms/noise/noisy_speech_1121..npy',
#  '../input/spectrograms/noise/noisy_speech_1808..npy',
#  '../input/spectrograms/noise/noisy_speech_1715..npy',
#  '../input/spectrograms/noise/noisy_speech_1117..npy',
#  '../input/spectrograms/noise/noisy_speech_1070..npy',
#  '../input/spectrograms/noise/noisy_speech_532..npy',
#  '../input/spectrograms/noise/noisy_speech_585..npy',
#  '../input/spectrograms/noise/noisy_speech_1486..npy',
#  '../input/spectrograms/noise/noisy_speech_718..npy',
#  '../input/spectrograms/noise/noisy_speech_1884..npy',
#  '../input/spectrograms/noise/noisy_speech_1147..npy',
#  '../input/spectrograms/noise/noisy_speech_1221..npy',
#  '../input/spectrograms/noise/noisy_speech_140..npy',
#  '../input/spectrograms/noise/noisy_speech_297..npy',
#  '../input/spectrograms/noise/noisy_speech_1771..npy',
#  '../input/spectrograms/noise/noisy_speech_276..npy',
#  '../input/spectrograms/noise/noisy_speech_1086..npy',
#  '../input/spectrograms/noise/noisy_speech_1723..npy',
#  '../input/spectrograms/noise/noisy_speech_1662..npy',
#  '../input/spectrograms/noise/noisy_speech_597..npy',
#  '../input/spectrograms/noise/noisy_speech_1090..npy',
#  '../input/spectrograms/noise/noisy_speech_139..npy',
#  '../input/spectrograms/noise/noisy_speech_1065..npy',
#  '../input/spectrograms/noise/noisy_speech_82..npy',
#  '../input/spectrograms/noise/noisy_speech_267..npy',
#  '../input/spectrograms/noise/noisy_speech_1825..npy',
#  '../input/spectrograms/noise/noisy_speech_744..npy',
#  '../input/spectrograms/noise/noisy_speech_706..npy',
#  '../input/spectrograms/noise/noisy_speech_658..npy',
#  '../input/spectrograms/noise/noisy_speech_1685..npy',
#  '../input/spectrograms/noise/noisy_speech_189..npy',
#  '../input/spectrograms/noise/noisy_speech_1348..npy',
#  '../input/spectrograms/noise/noisy_speech_121..npy',
#  '../input/spectrograms/noise/noisy_speech_554..npy',
#  '../input/spectrograms/noise/noisy_speech_1239..npy',
#  '../input/spectrograms/noise/noisy_speech_369..npy',
#  '../input/spectrograms/noise/noisy_speech_1103..npy',
#  '../input/spectrograms/noise/noisy_speech_7..npy',
#  '../input/spectrograms/noise/noisy_speech_1604..npy',
#  '../input/spectrograms/noise/noisy_speech_1222..npy',
#  '../input/spectrograms/noise/noisy_speech_503..npy',
#  '../input/spectrograms/noise/noisy_speech_996..npy',
#  '../input/spectrograms/noise/noisy_speech_1083..npy',
#  '../input/spectrograms/noise/noisy_speech_1028..npy',
#  '../input/spectrograms/noise/noisy_speech_514..npy',
#  '../input/spectrograms/noise/noisy_speech_703..npy',
#  '../input/spectrograms/noise/noisy_speech_1401..npy',
#  '../input/spectrograms/noise/noisy_speech_1643..npy',
#  '../input/spectrograms/noise/noisy_speech_325..npy',
#  '../input/spectrograms/noise/noisy_speech_938..npy',
#  '../input/spectrograms/noise/noisy_speech_1..npy',
#  '../input/spectrograms/noise/noisy_speech_43..npy',
#  '../input/spectrograms/noise/noisy_speech_1990..npy',
#  '../input/spectrograms/noise/noisy_speech_1997..npy',
#  '../input/spectrograms/noise/noisy_speech_29..npy',
#  '../input/spectrograms/noise/noisy_speech_1072..npy',
#  '../input/spectrograms/noise/noisy_speech_347..npy',
#  '../input/spectrograms/noise/noisy_speech_1607..npy',
#  '../input/spectrograms/noise/noisy_speech_501..npy',
#  '../input/spectrograms/noise/noisy_speech_1940..npy',
#  '../input/spectrograms/noise/noisy_speech_1692..npy',
#  '../input/spectrograms/noise/noisy_speech_28..npy',
#  '../input/spectrograms/noise/noisy_speech_34..npy',
#  '../input/spectrograms/noise/noisy_speech_682..npy',
#  '../input/spectrograms/noise/noisy_speech_538..npy',
#  '../input/spectrograms/noise/noisy_speech_1362..npy',
#  '../input/spectrograms/noise/noisy_speech_76..npy',
#  '../input/spectrograms/noise/noisy_speech_358..npy',
#  '../input/spectrograms/noise/noisy_speech_692..npy',
#  '../input/spectrograms/noise/noisy_speech_1092..npy',
#  '../input/spectrograms/noise/noisy_speech_1618..npy',
#  '../input/spectrograms/noise/noisy_speech_810..npy',
#  '../input/spectrograms/noise/noisy_speech_1742..npy',
#  '../input/spectrograms/noise/noisy_speech_253..npy',
#  '../input/spectrograms/noise/noisy_speech_1054..npy',
#  '../input/spectrograms/noise/noisy_speech_1766..npy',
#  '../input/spectrograms/noise/noisy_speech_408..npy',
#  '../input/spectrograms/noise/noisy_speech_12..npy',
#  '../input/spectrograms/noise/noisy_speech_1129..npy',
#  '../input/spectrograms/noise/noisy_speech_1979..npy',
#  '../input/spectrograms/noise/noisy_speech_1334..npy',
#  '../input/spectrograms/noise/noisy_speech_857..npy',
#  '../input/spectrograms/noise/noisy_speech_2026..npy',
#  '../input/spectrograms/noise/noisy_speech_854..npy',
#  '../input/spectrograms/noise/noisy_speech_543..npy',
#  '../input/spectrograms/noise/noisy_speech_640..npy',
#  '../input/spectrograms/noise/noisy_speech_330..npy',
#  '../input/spectrograms/noise/noisy_speech_1006..npy',
#  '../input/spectrograms/noise/noisy_speech_1402..npy',
#  '../input/spectrograms/noise/noisy_speech_1636..npy',
#  '../input/spectrograms/noise/noisy_speech_1228..npy',
#  '../input/spectrograms/noise/noisy_speech_1793..npy',
#  '../input/spectrograms/noise/noisy_speech_1349..npy',
#  '../input/spectrograms/noise/noisy_speech_1816..npy',
#  '../input/spectrograms/noise/noisy_speech_1830..npy',
#  '../input/spectrograms/noise/noisy_speech_737..npy',
#  '../input/spectrograms/noise/noisy_speech_295..npy',
#  '../input/spectrograms/noise/noisy_speech_1412..npy',
#  '../input/spectrograms/noise/noisy_speech_749..npy',
#  '../input/spectrograms/noise/noisy_speech_734..npy',
#  '../input/spectrograms/noise/noisy_speech_205..npy',
#  '../input/spectrograms/noise/noisy_speech_1861..npy',
#  '../input/spectrograms/noise/noisy_speech_145..npy',
#  '../input/spectrograms/noise/noisy_speech_1664..npy',
#  '../input/spectrograms/noise/noisy_speech_877..npy',
#  '../input/spectrograms/noise/noisy_speech_1780..npy',
#  '../input/spectrograms/noise/noisy_speech_1657..npy',
#  '../input/spectrograms/noise/noisy_speech_1484..npy',
#  '../input/spectrograms/noise/noisy_speech_218..npy',
#  '../input/spectrograms/noise/noisy_speech_1626..npy',
#  '../input/spectrograms/noise/noisy_speech_447..npy',
#  '../input/spectrograms/noise/noisy_speech_711..npy',
#  '../input/spectrograms/noise/noisy_speech_2029..npy',
#  '../input/spectrograms/noise/noisy_speech_1927..npy',
#  '../input/spectrograms/noise/noisy_speech_1333..npy',
#  '../input/spectrograms/noise/noisy_speech_16..npy',
#  '../input/spectrograms/noise/noisy_speech_571..npy',
#  '../input/spectrograms/noise/noisy_speech_132..npy',
#  '../input/spectrograms/noise/noisy_speech_187..npy',
#  '../input/spectrograms/noise/noisy_speech_1703..npy',
#  '../input/spectrograms/noise/noisy_speech_1660..npy',
#  '../input/spectrograms/noise/noisy_speech_1930..npy',
#  '../input/spectrograms/noise/noisy_speech_1872..npy',
#  '../input/spectrograms/noise/noisy_speech_570..npy',
#  '../input/spectrograms/noise/noisy_speech_536..npy',
#  '../input/spectrograms/noise/noisy_speech_963..npy',
#  '../input/spectrograms/noise/noisy_speech_57..npy',
#  '../input/spectrograms/noise/noisy_speech_592..npy',
#  '../input/spectrograms/noise/noisy_speech_54..npy',
#  '../input/spectrograms/noise/noisy_speech_678..npy',
#  '../input/spectrograms/noise/noisy_speech_264..npy',
#  '../input/spectrograms/noise/noisy_speech_728..npy',
#  '../input/spectrograms/noise/noisy_speech_748..npy',
#  '../input/spectrograms/noise/noisy_speech_25..npy',
#  '../input/spectrograms/noise/noisy_speech_1796..npy',
#  '../input/spectrograms/noise/noisy_speech_107..npy',
#  '../input/spectrograms/noise/noisy_speech_2053..npy',
#  '../input/spectrograms/noise/noisy_speech_1731..npy',
#  '../input/spectrograms/noise/noisy_speech_344..npy',
#  '../input/spectrograms/noise/noisy_speech_1602..npy',
#  '../input/spectrograms/noise/noisy_speech_577..npy',
#  '../input/spectrograms/noise/noisy_speech_105..npy',
#  '../input/spectrograms/noise/noisy_speech_1118..npy',
#  '../input/spectrograms/noise/noisy_speech_2024..npy',
#  '../input/spectrograms/noise/noisy_speech_1839..npy',
#  '../input/spectrograms/noise/noisy_speech_834..npy',
#  '../input/spectrograms/noise/noisy_speech_174..npy',
#  '../input/spectrograms/noise/noisy_speech_23..npy',
#  '../input/spectrograms/noise/noisy_speech_1452..npy',
#  '../input/spectrograms/noise/noisy_speech_803..npy',
#  '../input/spectrograms/noise/noisy_speech_1310..npy',
#  '../input/spectrograms/noise/noisy_speech_1346..npy',
#  '../input/spectrograms/noise/noisy_speech_1920..npy',
#  '../input/spectrograms/noise/noisy_speech_1803..npy',
#  '../input/spectrograms/noise/noisy_speech_1744..npy',
#  '../input/spectrograms/noise/noisy_speech_917..npy',
#  '../input/spectrograms/noise/noisy_speech_1426..npy',
#  '../input/spectrograms/noise/noisy_speech_520..npy',
#  '../input/spectrograms/noise/noisy_speech_499..npy',
#  '../input/spectrograms/noise/noisy_speech_450..npy',
#  '../input/spectrograms/noise/noisy_speech_1586..npy',
#  '../input/spectrograms/noise/noisy_speech_1153..npy',
#  '../input/spectrograms/noise/noisy_speech_2032..npy',
#  '../input/spectrograms/noise/noisy_speech_1032..npy',
#  '../input/spectrograms/noise/noisy_speech_1640..npy',
#  '../input/spectrograms/noise/noisy_speech_108..npy',
#  '../input/spectrograms/noise/noisy_speech_96..npy',
#  '../input/spectrograms/noise/noisy_speech_221..npy',
#  '../input/spectrograms/noise/noisy_speech_1787..npy',
#  '../input/spectrograms/noise/noisy_speech_773..npy',
#  '../input/spectrograms/noise/noisy_speech_914..npy',
#  '../input/spectrograms/noise/noisy_speech_1983..npy',
#  '../input/spectrograms/noise/noisy_speech_2038..npy',
#  '../input/spectrograms/noise/noisy_speech_329..npy',
#  '../input/spectrograms/noise/noisy_speech_418..npy',
#  '../input/spectrograms/noise/noisy_speech_352..npy',
#  '../input/spectrograms/noise/noisy_speech_98..npy',
#  '../input/spectrograms/noise/noisy_speech_1448..npy',
#  '../input/spectrograms/noise/noisy_speech_1302..npy',
#  '../input/spectrograms/noise/noisy_speech_2068..npy',
#  '../input/spectrograms/noise/noisy_speech_1023..npy',
#  '../input/spectrograms/noise/noisy_speech_232..npy',
#  '../input/spectrograms/noise/noisy_speech_382..npy',
#  '../input/spectrograms/noise/noisy_speech_849..npy',
#  '../input/spectrograms/noise/noisy_speech_185..npy',
#  '../input/spectrograms/noise/noisy_speech_1150..npy',
#  '../input/spectrograms/noise/noisy_speech_458..npy',
#  '../input/spectrograms/noise/noisy_speech_214..npy',
#  '../input/spectrograms/noise/noisy_speech_265..npy',
#  '../input/spectrograms/noise/noisy_speech_452..npy',
#  '../input/spectrograms/noise/noisy_speech_182..npy',
#  '../input/spectrograms/noise/noisy_speech_1440..npy',
#  '../input/spectrograms/noise/noisy_speech_1857..npy',
#  '../input/spectrograms/noise/noisy_speech_1987..npy',
#  '../input/spectrograms/noise/noisy_speech_1928..npy',
#  '../input/spectrograms/noise/noisy_speech_1527..npy',
#  '../input/spectrograms/noise/noisy_speech_1674..npy',
#  '../input/spectrograms/noise/noisy_speech_1590..npy',
#  '../input/spectrograms/noise/noisy_speech_1209..npy',
#  '../input/spectrograms/noise/noisy_speech_1658..npy',
#  '../input/spectrograms/noise/noisy_speech_993..npy',
#  '../input/spectrograms/noise/noisy_speech_669..npy',
#  '../input/spectrograms/noise/noisy_speech_2039..npy',
#  '../input/spectrograms/noise/noisy_speech_52..npy',
#  '../input/spectrograms/noise/noisy_speech_478..npy',
#  '../input/spectrograms/noise/noisy_speech_685..npy',
#  '../input/spectrograms/noise/noisy_speech_184..npy',
#  '../input/spectrograms/noise/noisy_speech_225..npy',
#  '../input/spectrograms/noise/noisy_speech_1958..npy',
#  '../input/spectrograms/noise/noisy_speech_1096..npy',
#  '../input/spectrograms/noise/noisy_speech_587..npy',
#  '../input/spectrograms/noise/noisy_speech_151..npy',
#  '../input/spectrograms/noise/noisy_speech_2049..npy',
#  '../input/spectrograms/noise/noisy_speech_2055..npy',
#  '../input/spectrograms/noise/noisy_speech_180..npy',
#  '../input/spectrograms/noise/noisy_speech_1851..npy',
#  '../input/spectrograms/noise/noisy_speech_1942..npy',
#  '../input/spectrograms/noise/noisy_speech_936..npy',
#  '../input/spectrograms/noise/noisy_speech_426..npy',
#  '../input/spectrograms/noise/noisy_speech_498..npy',
#  '../input/spectrograms/noise/noisy_speech_1795..npy',
#  '../input/spectrograms/noise/noisy_speech_708..npy',
#  '../input/spectrograms/noise/noisy_speech_948..npy',
#  '../input/spectrograms/noise/noisy_speech_1764..npy',
#  '../input/spectrograms/noise/noisy_speech_166..npy',
#  '../input/spectrograms/noise/noisy_speech_1644..npy',
#  '../input/spectrograms/noise/noisy_speech_1407..npy',
#  '../input/spectrograms/noise/noisy_speech_1236..npy',
#  '../input/spectrograms/noise/noisy_speech_1066..npy',
#  '../input/spectrograms/noise/noisy_speech_694..npy',
#  '../input/spectrograms/noise/noisy_speech_1399..npy',
#  '../input/spectrograms/noise/noisy_speech_1354..npy',
#  '../input/spectrograms/noise/noisy_speech_1157..npy',
#  '../input/spectrograms/noise/noisy_speech_1937..npy',
#  ...]

# %%
train_dataset[69][1].unsqueeze(0).shape
# Out:
# torch.Size([1, 1, 512, 219])

# %%
# from the model 

loss =0
sample = 394
model.eval()
y_pred = None
with torch.inference_mode():
    y_pred = model(train_dataset[sample][1].unsqueeze(0).to(device))
    loss = criterion(y_pred,train_dataset[sample][0].unsqueeze(0).to(device) )
    print(f"Loss is {loss.item()}")
# Out:
# Loss is 0.018210144713521004

# %%
print(train_dataset[129][1].squeeze().numpy())
# sf.write("test3.wav",train_dataset[69][1].squeeze().numpy(),  16000)
# Out:
# [[0.01267815 0.3039472  0.26735932 ... 0.33675927 0.39361864 0.31637222]
#  [0.06704021 0.32708612 0.3727473  ... 0.35802642 0.34010035 0.35781342]
#  [0.1277546  0.32803494 0.3127188  ... 0.3956848  0.35964116 0.45192522]
#  ...
#  [0.         0.         0.         ... 0.15113997 0.3725989  0.20799088]
#  [0.         0.         0.         ... 0.17102471 0.30001432 0.304568  ]
#  [0.         0.         0.         ... 0.28665537 0.28387505 0.27228588]]

# %%
input_signals = generate_sound(train_dataset[269][0].unsqueeze(0), train_dataset.noisy_speech_paths[sample])
output_signals = generate_sound(y_pred.squeeze().squeeze(), train_dataset.clean_speech_paths[sample])
# Out:
# type of the array is <class 'numpy.ndarray'>
# shape of the spec is (512, 219)
# type of the array is <class 'numpy.ndarray'>
# shape of the spec is (512, 219)

# %%
y_pred.shape
# Out:
# torch.Size([1, 1, 512, 219])

# %%
sf.write("test3_input.wav",input_signals,  16000)
sf.write("test3_output.wav",output_signals,  16000)

# %%
input_signals
# Out:
# array([ 2.2860274e-04, -5.9074559e-06, -9.0649199e-05, ...,
#         2.8617153e-02,  2.5126541e-02,  2.0106634e-02], dtype=float32)

# %%
output_signals
# Out:
# array([ 1.7694125e-03,  1.8077050e-03, -1.5632421e-04, ...,
#         1.9253884e-01,  1.5552570e-01,  9.7305819e-02], dtype=float32)

# %%
ipd.Audio(input_signals, rate = 16000)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
train_dataset[269][1].shape
# Out:
# torch.Size([1, 512, 219])
